# %%
# Selenium imports
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
chrome_options = Options()
chrome_options.headless = True
from webdriver_manager.chrome import ChromeDriverManager

# Other imports
import pandas as pd
import regex as re
import requests
from bs4 import BeautifulSoup

import time
from time import sleep
# Out:
# C:\Users\Felipe\AppData\Local\Temp\ipykernel_14728\233382157.py:7: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   chrome_options.headless = True

# %%
# General Helpers

headers = {
    "Accept-Language": "en-US,en;q=0.5",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; WOW64; rv:40.0) Gecko/20100101 Firefox/40.0",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8",
    "Referer": "http://thewebsite.com",
    "Connection": "keep-alive"}

def price_multiple_replace(text, dict=None):
    """
    Multiple regex replacements (to replace in key, replacement in value) 
    """
    if not dict:
        dict = {"," : ".", "." : ""}
        
    # Create a regular expression  from the dictionary keys
    regex = re.compile("(%s)" % "|".join(map(re.escape, dict.keys())))
    
    # For each match, look-up corresponding value in dictionary
    return float(regex.sub(lambda mo: dict[mo.string[mo.start():mo.end()]], text))

# %% [markdown]
# # Argenprop

# %%
def scrape_argenprop(url_ap):
    
    result_ap = requests.get(url_ap, headers=headers)

    soup_ap = BeautifulSoup(result_ap.text, 'lxml')

    all_data_ap = []

    # Links
    base_link = 'https://www.argenprop.com'
    div_container = soup_ap.find_all('div',{'class':'listing__item'})
    links_ap = []
    for div in div_container:
        a_link = div.find_all('a', href=True)
        last_link = a_link[0]['href']
        links_ap.append(base_link+last_link)
    all_data_ap.append(links_ap)


    # Service
    all_data_ap.append(['argen_prop']*len(links_ap))

    # City
    city_ap = soup_ap.find_all('p', {'class':'card__title--primary show-mobile'})
    city_ap = [c.text for c in city_ap]
    all_data_ap.append(city_ap)

    # Adress
    address_ap = soup_ap.find_all(['h2','p'], {'class':'card__address'})
    address_ap = [c.text.strip() for c in address_ap]
    address_ap = [re.findall('.+', str(c))[0] for c in address_ap]
    all_data_ap.append(address_ap)

    # Property Type
    # property_type_ap = soup_ap.find_all('p', {'class':'card__title--primary hide-mobile'})
    # property_type_ap = [c.text.split(' ')[0] for c in property_type_ap]
    if 'casa' in url_ap:
        property_type_ap = ['casa']*len(links_ap)
    else:
        property_type_ap = ['departamento']*len(links_ap)
    all_data_ap.append(property_type_ap)

    # Contract type
    # contract_type_ap = soup_ap.find_all('p', {'class':'card__title--primary hide-mobile'})
    # contract_type_ap = [c.text.split(' ')[2] for c in contract_type_ap]
    if 'alquiler' in url_ap:
        contract_type_ap = ['alquiler']*len(links_ap)
    else:
        contract_type_ap = ['venta']*len(links_ap)
    all_data_ap.append(contract_type_ap)


    # Rooms and Squared Meters
    ul_container = soup_ap.find_all('ul', {'class':'card__main-features'})
    rooms_ap = []
    squared_meters_ap = []
    for ul in ul_container:
        
        amb = re.findall('(\d+)\s(?:ambiente|dorm\.)', str(ul.find_all('span')))
        if len(amb)>0:
            rooms_ap.append(int(amb[0]))
        else:
            rooms_ap.append(1)
            
        m2 = re.findall('(\d+)\s*m²', str(ul.find_all('span')))
        if len(m2)>0:
            squared_meters_ap.append(int(m2[0]))
        else:
            squared_meters_ap.append(0)
    all_data_ap.append(rooms_ap)
    all_data_ap.append(squared_meters_ap)


    # Price and currency type
    buy_rent_currency_ap = []
    buy_rent_price_ap = []

    expensas_currency_ap = []
    expensas_price_ap = []

    all_currency_and_price_ap = soup_ap.find_all('p', {'class':'card__price'})
    all_currency_and_price_ap = [c.text for c in all_currency_and_price_ap]
    all_currency_and_price_ap = [re.findall('(USD|\$)\s?(\d+(?:[,.]\d+)*)', str(c)) for c in all_currency_and_price_ap]

    for cp in all_currency_and_price_ap:
        if len(cp)>0:
            buy_rent_currency_ap.append(cp[0][0])
            buy_rent_price_ap.append(price_multiple_replace(cp[0][1]))
            if len(cp)>1:
                expensas_currency_ap.append(cp[1][0])
                expensas_price_ap.append(price_multiple_replace(cp[1][1]))
            else:
                expensas_currency_ap.append('consultar_precio')
                expensas_price_ap.append(0)
        else:
            buy_rent_currency_ap.append('consultar_precio')
            buy_rent_price_ap.append(0)
            expensas_currency_ap.append('consultar_precio')
            expensas_price_ap.append(0)
            
    all_data_ap.append(buy_rent_currency_ap)
    all_data_ap.append(expensas_currency_ap)
    all_data_ap.append(buy_rent_price_ap)
    all_data_ap.append(expensas_price_ap)

    return all_data_ap

# %%
all_url_ap = [  'https://www.argenprop.com/departamento-venta-pagina-',
                'https://www.argenprop.com/departamento-alquiler-y-alquiler-temporal-pagina-',
                'https://www.argenprop.com/casa-venta-pagina-',
                'https://www.argenprop.com/casa-alquiler-y-alquiler-temporal-pagina-']

cantidad_paginas_a_scrapear = {
                                'departamentos venta':50,
                                'departamentos alquiler':50,
                                'casas venta':50,
                                'casas alquiler':50,
                                }

total_pages = sum(cantidad_paginas_a_scrapear.values())
page_counter = 0

t1 = time.time()

all_columns_ap = []
for i_url, url_ap in enumerate(all_url_ap): # iterate general URLs
    cant_pag = list(cantidad_paginas_a_scrapear.values())[i_url]
    categorie = list(cantidad_paginas_a_scrapear.keys())[i_url]
    for pag in range(cant_pag): # iterate paginas
        
        page_counter += 1
        print(f'Scraping {categorie}, pag. {pag+1} of {cant_pag} from this category. {page_counter} of {total_pages} total pages.')
        
        this_url = url_ap+str(pag+1)
        
        all_columns_ap.append(scrape_argenprop(this_url))


t2 = time.time()

print(f'This took {(t2-t1)/60} minutes, or {round((t2-t1)/200)} seconds per page.')
# Out:
# Scraping departamentos venta, pag. 1 of 50 from this category. 1 from 200 total pages.
# Scraping departamentos venta, pag. 2 of 50 from this category. 2 from 200 total pages.
# Scraping departamentos venta, pag. 3 of 50 from this category. 3 from 200 total pages.
# Scraping departamentos venta, pag. 4 of 50 from this category. 4 from 200 total pages.
# Scraping departamentos venta, pag. 5 of 50 from this category. 5 from 200 total pages.
# Scraping departamentos venta, pag. 6 of 50 from this category. 6 from 200 total pages.
# Scraping departamentos venta, pag. 7 of 50 from this category. 7 from 200 total pages.
# Scraping departamentos venta, pag. 8 of 50 from this category. 8 from 200 total pages.
# Scraping departamentos venta, pag. 9 of 50 from this category. 9 from 200 total pages.
# Scraping departamentos venta, pag. 10 of 50 from this category. 10 from 200 total pages.
# Scraping departamentos venta, pag. 11 of 50 from this category. 11 from 200 total pages.
# Scraping departamentos venta, pag. 12 of 50 from this category. 12 from 200 total pages.
# Scraping departamentos venta, pag. 13 of 50 from this category. 13 from 200 total pages.
# Scraping departamentos venta, pag. 14 of 50 from this category. 14 from 200 total pages.
# Scraping departamentos venta, pag. 15 of 50 from this category. 15 from 200 total pages.
# Scraping departamentos venta, pag. 16 of 50 from this category. 16 from 200 total pages.
# Scraping departamentos venta, pag. 17 of 50 from this category. 17 from 200 total pages.
# Scraping departamentos venta, pag. 18 of 50 from this category. 18 from 200 total pages.
# Scraping departamentos venta, pag. 19 of 50 from this category. 19 from 200 total pages.
# Scraping departamentos venta, pag. 20 of 50 from this category. 20 from 200 total pages.
# Scraping departamentos venta, pag. 21 of 50 from this category. 21 from 200 total pages.
# Scraping departamentos venta, pag. 22 of 50 from this category. 22 from 200 total pages.
# Scraping departamentos venta, pag. 23 of 50 from this category. 23 from 200 total pages.
# Scraping departamentos venta, pag. 24 of 50 from this category. 24 from 200 total pages.
# Scraping departamentos venta, pag. 25 of 50 from this category. 25 from 200 total pages.
# Scraping departamentos venta, pag. 26 of 50 from this category. 26 from 200 total pages.
# Scraping departamentos venta, pag. 27 of 50 from this category. 27 from 200 total pages.
# Scraping departamentos venta, pag. 28 of 50 from this category. 28 from 200 total pages.
# Scraping departamentos venta, pag. 29 of 50 from this category. 29 from 200 total pages.
# Scraping departamentos venta, pag. 30 of 50 from this category. 30 from 200 total pages.
# Scraping departamentos venta, pag. 31 of 50 from this category. 31 from 200 total pages.
# Scraping departamentos venta, pag. 32 of 50 from this category. 32 from 200 total pages.
# Scraping departamentos venta, pag. 33 of 50 from this category. 33 from 200 total pages.
# Scraping departamentos venta, pag. 34 of 50 from this category. 34 from 200 total pages.
# Scraping departamentos venta, pag. 35 of 50 from this category. 35 from 200 total pages.
# Scraping departamentos venta, pag. 36 of 50 from this category. 36 from 200 total pages.
# Scraping departamentos venta, pag. 37 of 50 from this category. 37 from 200 total pages.
# Scraping departamentos venta, pag. 38 of 50 from this category. 38 from 200 total pages.
# Scraping departamentos venta, pag. 39 of 50 from this category. 39 from 200 total pages.
# Scraping departamentos venta, pag. 40 of 50 from this category. 40 from 200 total pages.
# Scraping departamentos venta, pag. 41 of 50 from this category. 41 from 200 total pages.
# Scraping departamentos venta, pag. 42 of 50 from this category. 42 from 200 total pages.
# Scraping departamentos venta, pag. 43 of 50 from this category. 43 from 200 total pages.
# Scraping departamentos venta, pag. 44 of 50 from this category. 44 from 200 total pages.
# Scraping departamentos venta, pag. 45 of 50 from this category. 45 from 200 total pages.
# Scraping departamentos venta, pag. 46 of 50 from this category. 46 from 200 total pages.
# Scraping departamentos venta, pag. 47 of 50 from this category. 47 from 200 total pages.
# Scraping departamentos venta, pag. 48 of 50 from this category. 48 from 200 total pages.
# Scraping departamentos venta, pag. 49 of 50 from this category. 49 from 200 total pages.
# Scraping departamentos venta, pag. 50 of 50 from this category. 50 from 200 total pages.
# Scraping departamentos alquiler, pag. 1 of 50 from this category. 51 from 200 total pages.
# Scraping departamentos alquiler, pag. 2 of 50 from this category. 52 from 200 total pages.
# Scraping departamentos alquiler, pag. 3 of 50 from this category. 53 from 200 total pages.
# Scraping departamentos alquiler, pag. 4 of 50 from this category. 54 from 200 total pages.
# Scraping departamentos alquiler, pag. 5 of 50 from this category. 55 from 200 total pages.
# Scraping departamentos alquiler, pag. 6 of 50 from this category. 56 from 200 total pages.
# Scraping departamentos alquiler, pag. 7 of 50 from this category. 57 from 200 total pages.
# Scraping departamentos alquiler, pag. 8 of 50 from this category. 58 from 200 total pages.
# Scraping departamentos alquiler, pag. 9 of 50 from this category. 59 from 200 total pages.
# Scraping departamentos alquiler, pag. 10 of 50 from this category. 60 from 200 total pages.
# Scraping departamentos alquiler, pag. 11 of 50 from this category. 61 from 200 total pages.
# Scraping departamentos alquiler, pag. 12 of 50 from this category. 62 from 200 total pages.
# Scraping departamentos alquiler, pag. 13 of 50 from this category. 63 from 200 total pages.
# Scraping departamentos alquiler, pag. 14 of 50 from this category. 64 from 200 total pages.
# Scraping departamentos alquiler, pag. 15 of 50 from this category. 65 from 200 total pages.
# Scraping departamentos alquiler, pag. 16 of 50 from this category. 66 from 200 total pages.
# Scraping departamentos alquiler, pag. 17 of 50 from this category. 67 from 200 total pages.
# Scraping departamentos alquiler, pag. 18 of 50 from this category. 68 from 200 total pages.
# Scraping departamentos alquiler, pag. 19 of 50 from this category. 69 from 200 total pages.
# Scraping departamentos alquiler, pag. 20 of 50 from this category. 70 from 200 total pages.
# Scraping departamentos alquiler, pag. 21 of 50 from this category. 71 from 200 total pages.
# Scraping departamentos alquiler, pag. 22 of 50 from this category. 72 from 200 total pages.
# Scraping departamentos alquiler, pag. 23 of 50 from this category. 73 from 200 total pages.
# Scraping departamentos alquiler, pag. 24 of 50 from this category. 74 from 200 total pages.
# Scraping departamentos alquiler, pag. 25 of 50 from this category. 75 from 200 total pages.
# Scraping departamentos alquiler, pag. 26 of 50 from this category. 76 from 200 total pages.
# Scraping departamentos alquiler, pag. 27 of 50 from this category. 77 from 200 total pages.
# Scraping departamentos alquiler, pag. 28 of 50 from this category. 78 from 200 total pages.
# Scraping departamentos alquiler, pag. 29 of 50 from this category. 79 from 200 total pages.
# Scraping departamentos alquiler, pag. 30 of 50 from this category. 80 from 200 total pages.
# Scraping departamentos alquiler, pag. 31 of 50 from this category. 81 from 200 total pages.
# Scraping departamentos alquiler, pag. 32 of 50 from this category. 82 from 200 total pages.
# Scraping departamentos alquiler, pag. 33 of 50 from this category. 83 from 200 total pages.
# Scraping departamentos alquiler, pag. 34 of 50 from this category. 84 from 200 total pages.
# Scraping departamentos alquiler, pag. 35 of 50 from this category. 85 from 200 total pages.
# Scraping departamentos alquiler, pag. 36 of 50 from this category. 86 from 200 total pages.
# Scraping departamentos alquiler, pag. 37 of 50 from this category. 87 from 200 total pages.
# Scraping departamentos alquiler, pag. 38 of 50 from this category. 88 from 200 total pages.
# Scraping departamentos alquiler, pag. 39 of 50 from this category. 89 from 200 total pages.
# Scraping departamentos alquiler, pag. 40 of 50 from this category. 90 from 200 total pages.
# Scraping departamentos alquiler, pag. 41 of 50 from this category. 91 from 200 total pages.
# Scraping departamentos alquiler, pag. 42 of 50 from this category. 92 from 200 total pages.
# Scraping departamentos alquiler, pag. 43 of 50 from this category. 93 from 200 total pages.
# Scraping departamentos alquiler, pag. 44 of 50 from this category. 94 from 200 total pages.
# Scraping departamentos alquiler, pag. 45 of 50 from this category. 95 from 200 total pages.
# Scraping departamentos alquiler, pag. 46 of 50 from this category. 96 from 200 total pages.
# Scraping departamentos alquiler, pag. 47 of 50 from this category. 97 from 200 total pages.
# Scraping departamentos alquiler, pag. 48 of 50 from this category. 98 from 200 total pages.
# Scraping departamentos alquiler, pag. 49 of 50 from this category. 99 from 200 total pages.
# Scraping departamentos alquiler, pag. 50 of 50 from this category. 100 from 200 total pages.
# Scraping casas venta, pag. 1 of 50 from this category. 101 from 200 total pages.
# Scraping casas venta, pag. 2 of 50 from this category. 102 from 200 total pages.
# Scraping casas venta, pag. 3 of 50 from this category. 103 from 200 total pages.
# Scraping casas venta, pag. 4 of 50 from this category. 104 from 200 total pages.
# Scraping casas venta, pag. 5 of 50 from this category. 105 from 200 total pages.
# Scraping casas venta, pag. 6 of 50 from this category. 106 from 200 total pages.
# Scraping casas venta, pag. 7 of 50 from this category. 107 from 200 total pages.
# Scraping casas venta, pag. 8 of 50 from this category. 108 from 200 total pages.
# Scraping casas venta, pag. 9 of 50 from this category. 109 from 200 total pages.
# Scraping casas venta, pag. 10 of 50 from this category. 110 from 200 total pages.
# Scraping casas venta, pag. 11 of 50 from this category. 111 from 200 total pages.
# Scraping casas venta, pag. 12 of 50 from this category. 112 from 200 total pages.
# Scraping casas venta, pag. 13 of 50 from this category. 113 from 200 total pages.
# Scraping casas venta, pag. 14 of 50 from this category. 114 from 200 total pages.
# Scraping casas venta, pag. 15 of 50 from this category. 115 from 200 total pages.
# Scraping casas venta, pag. 16 of 50 from this category. 116 from 200 total pages.
# Scraping casas venta, pag. 17 of 50 from this category. 117 from 200 total pages.
# Scraping casas venta, pag. 18 of 50 from this category. 118 from 200 total pages.
# Scraping casas venta, pag. 19 of 50 from this category. 119 from 200 total pages.
# Scraping casas venta, pag. 20 of 50 from this category. 120 from 200 total pages.
# Scraping casas venta, pag. 21 of 50 from this category. 121 from 200 total pages.
# Scraping casas venta, pag. 22 of 50 from this category. 122 from 200 total pages.
# Scraping casas venta, pag. 23 of 50 from this category. 123 from 200 total pages.
# Scraping casas venta, pag. 24 of 50 from this category. 124 from 200 total pages.
# Scraping casas venta, pag. 25 of 50 from this category. 125 from 200 total pages.
# Scraping casas venta, pag. 26 of 50 from this category. 126 from 200 total pages.
# Scraping casas venta, pag. 27 of 50 from this category. 127 from 200 total pages.
# Scraping casas venta, pag. 28 of 50 from this category. 128 from 200 total pages.
# Scraping casas venta, pag. 29 of 50 from this category. 129 from 200 total pages.
# Scraping casas venta, pag. 30 of 50 from this category. 130 from 200 total pages.
# Scraping casas venta, pag. 31 of 50 from this category. 131 from 200 total pages.
# Scraping casas venta, pag. 32 of 50 from this category. 132 from 200 total pages.
# Scraping casas venta, pag. 33 of 50 from this category. 133 from 200 total pages.
# Scraping casas venta, pag. 34 of 50 from this category. 134 from 200 total pages.
# Scraping casas venta, pag. 35 of 50 from this category. 135 from 200 total pages.
# Scraping casas venta, pag. 36 of 50 from this category. 136 from 200 total pages.
# Scraping casas venta, pag. 37 of 50 from this category. 137 from 200 total pages.
# Scraping casas venta, pag. 38 of 50 from this category. 138 from 200 total pages.
# Scraping casas venta, pag. 39 of 50 from this category. 139 from 200 total pages.
# Scraping casas venta, pag. 40 of 50 from this category. 140 from 200 total pages.
# Scraping casas venta, pag. 41 of 50 from this category. 141 from 200 total pages.
# Scraping casas venta, pag. 42 of 50 from this category. 142 from 200 total pages.
# Scraping casas venta, pag. 43 of 50 from this category. 143 from 200 total pages.
# Scraping casas venta, pag. 44 of 50 from this category. 144 from 200 total pages.
# Scraping casas venta, pag. 45 of 50 from this category. 145 from 200 total pages.
# Scraping casas venta, pag. 46 of 50 from this category. 146 from 200 total pages.
# Scraping casas venta, pag. 47 of 50 from this category. 147 from 200 total pages.
# Scraping casas venta, pag. 48 of 50 from this category. 148 from 200 total pages.
# Scraping casas venta, pag. 49 of 50 from this category. 149 from 200 total pages.
# Scraping casas venta, pag. 50 of 50 from this category. 150 from 200 total pages.
# Scraping casas alquiler, pag. 1 of 50 from this category. 151 from 200 total pages.
# Scraping casas alquiler, pag. 2 of 50 from this category. 152 from 200 total pages.
# Scraping casas alquiler, pag. 3 of 50 from this category. 153 from 200 total pages.
# Scraping casas alquiler, pag. 4 of 50 from this category. 154 from 200 total pages.
# Scraping casas alquiler, pag. 5 of 50 from this category. 155 from 200 total pages.
# Scraping casas alquiler, pag. 6 of 50 from this category. 156 from 200 total pages.
# Scraping casas alquiler, pag. 7 of 50 from this category. 157 from 200 total pages.
# Scraping casas alquiler, pag. 8 of 50 from this category. 158 from 200 total pages.
# Scraping casas alquiler, pag. 9 of 50 from this category. 159 from 200 total pages.
# Scraping casas alquiler, pag. 10 of 50 from this category. 160 from 200 total pages.
# Scraping casas alquiler, pag. 11 of 50 from this category. 161 from 200 total pages.
# Scraping casas alquiler, pag. 12 of 50 from this category. 162 from 200 total pages.
# Scraping casas alquiler, pag. 13 of 50 from this category. 163 from 200 total pages.
# Scraping casas alquiler, pag. 14 of 50 from this category. 164 from 200 total pages.
# Scraping casas alquiler, pag. 15 of 50 from this category. 165 from 200 total pages.
# Scraping casas alquiler, pag. 16 of 50 from this category. 166 from 200 total pages.
# Scraping casas alquiler, pag. 17 of 50 from this category. 167 from 200 total pages.
# Scraping casas alquiler, pag. 18 of 50 from this category. 168 from 200 total pages.
# Scraping casas alquiler, pag. 19 of 50 from this category. 169 from 200 total pages.
# Scraping casas alquiler, pag. 20 of 50 from this category. 170 from 200 total pages.
# Scraping casas alquiler, pag. 21 of 50 from this category. 171 from 200 total pages.
# Scraping casas alquiler, pag. 22 of 50 from this category. 172 from 200 total pages.
# Scraping casas alquiler, pag. 23 of 50 from this category. 173 from 200 total pages.
# Scraping casas alquiler, pag. 24 of 50 from this category. 174 from 200 total pages.
# Scraping casas alquiler, pag. 25 of 50 from this category. 175 from 200 total pages.
# Scraping casas alquiler, pag. 26 of 50 from this category. 176 from 200 total pages.
# Scraping casas alquiler, pag. 27 of 50 from this category. 177 from 200 total pages.
# Scraping casas alquiler, pag. 28 of 50 from this category. 178 from 200 total pages.
# Scraping casas alquiler, pag. 29 of 50 from this category. 179 from 200 total pages.
# Scraping casas alquiler, pag. 30 of 50 from this category. 180 from 200 total pages.
# Scraping casas alquiler, pag. 31 of 50 from this category. 181 from 200 total pages.
# Scraping casas alquiler, pag. 32 of 50 from this category. 182 from 200 total pages.
# Scraping casas alquiler, pag. 33 of 50 from this category. 183 from 200 total pages.
# Scraping casas alquiler, pag. 34 of 50 from this category. 184 from 200 total pages.
# Scraping casas alquiler, pag. 35 of 50 from this category. 185 from 200 total pages.
# Scraping casas alquiler, pag. 36 of 50 from this category. 186 from 200 total pages.
# Scraping casas alquiler, pag. 37 of 50 from this category. 187 from 200 total pages.
# Scraping casas alquiler, pag. 38 of 50 from this category. 188 from 200 total pages.
# Scraping casas alquiler, pag. 39 of 50 from this category. 189 from 200 total pages.
# Scraping casas alquiler, pag. 40 of 50 from this category. 190 from 200 total pages.
# Scraping casas alquiler, pag. 41 of 50 from this category. 191 from 200 total pages.
# Scraping casas alquiler, pag. 42 of 50 from this category. 192 from 200 total pages.
# Scraping casas alquiler, pag. 43 of 50 from this category. 193 from 200 total pages.
# Scraping casas alquiler, pag. 44 of 50 from this category. 194 from 200 total pages.
# Scraping casas alquiler, pag. 45 of 50 from this category. 195 from 200 total pages.
# Scraping casas alquiler, pag. 46 of 50 from this category. 196 from 200 total pages.
# Scraping casas alquiler, pag. 47 of 50 from this category. 197 from 200 total pages.
# Scraping casas alquiler, pag. 48 of 50 from this category. 198 from 200 total pages.
# Scraping casas alquiler, pag. 49 of 50 from this category. 199 from 200 total pages.
# Scraping casas alquiler, pag. 50 of 50 from this category. 200 from 200 total pages.
# This took 2.9818658272425336 minutes, or 0.89455974817276 seconds per page.

# %% [markdown]
# # Mercado Libre

# %%
# Helpers
def get_ml_expensas_price(link_expensas):
    
    """
    For Mercado Libre
    """
    expensas_price = []

    for l_expensas in link_expensas:
        result = requests.get(l_expensas, headers=headers)
        soup = BeautifulSoup(result.text, 'lxml')
        try:
            exp = soup.find('p', {'class':'ui-pdp-color--GRAY ui-pdp-size--XSMALL ui-pdp-family--REGULAR ui-pdp-maintenance-fee-ltr'}).text
        except:
            exp = '0'
        expensas_price.append(exp)

    expensas_price = [re.findall('\d+(?:[,.]\d+)*', ex)[0] for ex in expensas_price]
    expensas_price = [int(price_multiple_replace(c)) for c in expensas_price]
    
    return expensas_price

# %%
def scrape_mercadolibre(url_ml, scrap_expensas_ML = True):

    result_ml = requests.get(url_ml, headers=headers)

    soup_ml = BeautifulSoup(result_ml.text, 'lxml')
        
    all_data_ml = []

    # Links
    div_container = soup_ml.find_all('div',{'class':'ui-search-result__wrapper shops__result-wrapper'})
    links_ml = []
    for div in div_container:
        a_link = div.find_all('a', href=True)
        link = a_link[0]['href']
        links_ml.append(link)
    all_data_ml.append(links_ml)

    # Service
    all_data_ml.append(['mercado_libre']*len(links_ml))

    # City
    city_ml = soup_ml.find_all('span', {'class':'ui-search-item__group__element ui-search-item__location shops__items-group-details'})
    city_ml = [c.text for c in city_ml]
    all_data_ml.append(city_ml)


    # Adress
    address_ml = soup_ml.find_all('span', {'class':'ui-search-item__group__element ui-search-item__location shops__items-group-details'})
    address_ml = [c.text.split(',')[0] for c in address_ml]
    all_data_ml.append(address_ml)

    # Property type
    # property_type_ml = soup_ml.find_all('span', {'class':'ui-search-item__group__element ui-search-item__subtitle shops__items-group-details'})
    # property_type_ml = [c.text.split(' en ')[0] for c in property_type_ml]
    if 'casa' in url_ml:
        property_type_ml = ['casa']*len(links_ml)
    else:
        property_type_ml = ['departamento']*len(links_ml)
    all_data_ml.append(property_type_ml)

    # Contract type
    # contract_type_ml = soup_ml.find_all('span', {'class':'ui-search-item__group__element ui-search-item__subtitle shops__items-group-details'})
    # contract_type_ml = [c.text.split(' en ')[-1] for c in contract_type_ml]
    if 'alquiler' in url_ml:
        contract_type_ml = ['alquiler']*len(links_ml)
    else:
        contract_type_ml = ['venta']*len(links_ml)
    all_data_ml.append(contract_type_ml)

    # Rooms and Squared Meters
    squared_meters = []
    rooms = []
    squared_meters_and_rooms = soup_ml.find_all('ul', {'class':'ui-search-card-attributes ui-search-item__group__element shops__items-group-details'})
    squared_meters_and_rooms = [sm_and_r.find_all('li', {'class':'ui-search-card-attributes__attribute'}) for sm_and_r in squared_meters_and_rooms]

    for sm_and_r in squared_meters_and_rooms:
        sm_and_r = [smr.text for smr in sm_and_r]
        if len(sm_and_r)==2:
            squared_meters.append(sm_and_r[0])
            rooms.append(sm_and_r[1])
        else:
            if 'm²' in sm_and_r[0]:
                squared_meters.append(sm_and_r[0])
                rooms.append('0')
            else:
                squared_meters.append('0')
                rooms.append(sm_and_r[0])
                
    squared_meters = [int(price_multiple_replace(sm.split(' ')[0])) for sm in squared_meters]
    rooms = [int(price_multiple_replace(r.split(' ')[0])) for r in rooms]
    all_data_ml.append(rooms)
    all_data_ml.append(squared_meters)


    # All Currency type
    buy_rent_currency_ml = soup_ml.find_all('span', {'class':'price-tag-symbol'})
    buy_rent_currency_ml = [c.text.replace('U$S', 'USD') for c in buy_rent_currency_ml]
    buy_rent_currency_ml = buy_rent_currency_ml[len(buy_rent_currency_ml)-len(links_ml):] # Eliminate those with no link
    expensas_currency_ml = ['$']*len(links_ml)
    all_data_ml.append(buy_rent_currency_ml)
    all_data_ml.append(expensas_currency_ml)


    # Buy Rent Price
    buy_rent_price_ml = []
    buy_rent_price_ml = soup_ml.find_all('span', {'class':'price-tag-fraction'})
    buy_rent_price_ml = [c.text for c in buy_rent_price_ml]
    buy_rent_price_ml = [int(price_multiple_replace(c)) for c in buy_rent_price_ml]
    buy_rent_price_ml = buy_rent_price_ml[len(buy_rent_price_ml)-len(links_ml):] # Eliminate those with no link
    all_data_ml.append(buy_rent_price_ml)


    # Expensas Price
    if scrap_expensas_ML:
        expensas_price = get_ml_expensas_price(links_ml)
    else:
        expensas_price = [0]*len(links_ml)
    all_data_ml.append(expensas_price)
    
    return all_data_ml

# %%
all_url_ml = ['https://inmuebles.mercadolibre.com.ar/departamentos/venta/_Desde_NRO_PAGINA_NoIndex_True',
              'https://inmuebles.mercadolibre.com.ar/departamentos/alquiler-temporario/_Desde_NRO_PAGINA_NoIndex_True',
              'https://inmuebles.mercadolibre.com.ar/casas/venta/_Desde_NRO_PAGINA_NoIndex_True',
              'https://inmuebles.mercadolibre.com.ar/casas/alquiler-temporario/_Desde_NRO_PAGINA_NoIndex_True']

cantidad_paginas_a_scrapear = {
                                'departamentos venta':30,
                                'departamentos alquiler':30,
                                'casas venta':30,
                                'casas alquiler':30,
                                }

total_pages = sum(cantidad_paginas_a_scrapear.values())
page_counter = 0

t1 = time.time()

all_columns_ml = []
for i_url, url_ml in enumerate(all_url_ml): # iterate general URLs
    cant_pag = list(cantidad_paginas_a_scrapear.values())[i_url]
    categorie = list(cantidad_paginas_a_scrapear.keys())[i_url]
    for pag in range(cant_pag): # iterate paginas
        
        page_counter += 1
        print(f'Scraping {categorie}, pag. {pag+1} of {cant_pag} from this category. {page_counter} of {total_pages} total pages.')
        
        pag_counter = (48*pag)+1
        
        this_url = url_ml.replace('NRO_PAGINA',str(pag_counter)) #define page number
        
        all_columns_ml.append(scrape_mercadolibre(this_url))

t2 = time.time()

print(f'This took {(t2-t1)/60} minutes, or {round((t2-t1)/200)} seconds per page.')
# Out:
# Scraping departamentos venta, pag. 1 of 30 from this category. 1 of 120 total pages.
# Scraping departamentos venta, pag. 2 of 30 from this category. 2 of 120 total pages.
# Scraping departamentos venta, pag. 3 of 30 from this category. 3 of 120 total pages.
# Scraping departamentos venta, pag. 4 of 30 from this category. 4 of 120 total pages.
# Scraping departamentos venta, pag. 5 of 30 from this category. 5 of 120 total pages.
# Scraping departamentos venta, pag. 6 of 30 from this category. 6 of 120 total pages.
# Scraping departamentos venta, pag. 7 of 30 from this category. 7 of 120 total pages.
# Scraping departamentos venta, pag. 8 of 30 from this category. 8 of 120 total pages.
# Scraping departamentos venta, pag. 9 of 30 from this category. 9 of 120 total pages.
# Scraping departamentos venta, pag. 10 of 30 from this category. 10 of 120 total pages.
# Scraping departamentos venta, pag. 11 of 30 from this category. 11 of 120 total pages.
# Scraping departamentos venta, pag. 12 of 30 from this category. 12 of 120 total pages.
# Scraping departamentos venta, pag. 13 of 30 from this category. 13 of 120 total pages.
# Scraping departamentos venta, pag. 14 of 30 from this category. 14 of 120 total pages.
# Scraping departamentos venta, pag. 15 of 30 from this category. 15 of 120 total pages.
# Scraping departamentos venta, pag. 16 of 30 from this category. 16 of 120 total pages.
# Scraping departamentos venta, pag. 17 of 30 from this category. 17 of 120 total pages.
# Scraping departamentos venta, pag. 18 of 30 from this category. 18 of 120 total pages.
# Scraping departamentos venta, pag. 19 of 30 from this category. 19 of 120 total pages.
# Scraping departamentos venta, pag. 20 of 30 from this category. 20 of 120 total pages.
# Scraping departamentos venta, pag. 21 of 30 from this category. 21 of 120 total pages.
# Scraping departamentos venta, pag. 22 of 30 from this category. 22 of 120 total pages.
# Scraping departamentos venta, pag. 23 of 30 from this category. 23 of 120 total pages.
# Scraping departamentos venta, pag. 24 of 30 from this category. 24 of 120 total pages.
# Scraping departamentos venta, pag. 25 of 30 from this category. 25 of 120 total pages.
# Scraping departamentos venta, pag. 26 of 30 from this category. 26 of 120 total pages.
# Scraping departamentos venta, pag. 27 of 30 from this category. 27 of 120 total pages.
# Scraping departamentos venta, pag. 28 of 30 from this category. 28 of 120 total pages.
# Scraping departamentos venta, pag. 29 of 30 from this category. 29 of 120 total pages.
# Scraping departamentos venta, pag. 30 of 30 from this category. 30 of 120 total pages.
# Scraping departamentos alquiler, pag. 1 of 30 from this category. 31 of 120 total pages.
# Scraping departamentos alquiler, pag. 2 of 30 from this category. 32 of 120 total pages.
# Scraping departamentos alquiler, pag. 3 of 30 from this category. 33 of 120 total pages.
# Scraping departamentos alquiler, pag. 4 of 30 from this category. 34 of 120 total pages.
# Scraping departamentos alquiler, pag. 5 of 30 from this category. 35 of 120 total pages.
# Scraping departamentos alquiler, pag. 6 of 30 from this category. 36 of 120 total pages.
# Scraping departamentos alquiler, pag. 7 of 30 from this category. 37 of 120 total pages.
# Scraping departamentos alquiler, pag. 8 of 30 from this category. 38 of 120 total pages.
# Scraping departamentos alquiler, pag. 9 of 30 from this category. 39 of 120 total pages.
# Scraping departamentos alquiler, pag. 10 of 30 from this category. 40 of 120 total pages.
# Scraping departamentos alquiler, pag. 11 of 30 from this category. 41 of 120 total pages.
# Scraping departamentos alquiler, pag. 12 of 30 from this category. 42 of 120 total pages.
# Scraping departamentos alquiler, pag. 13 of 30 from this category. 43 of 120 total pages.
# Scraping departamentos alquiler, pag. 14 of 30 from this category. 44 of 120 total pages.
# Scraping departamentos alquiler, pag. 15 of 30 from this category. 45 of 120 total pages.
# Scraping departamentos alquiler, pag. 16 of 30 from this category. 46 of 120 total pages.
# Scraping departamentos alquiler, pag. 17 of 30 from this category. 47 of 120 total pages.
# Scraping departamentos alquiler, pag. 18 of 30 from this category. 48 of 120 total pages.
# Scraping departamentos alquiler, pag. 19 of 30 from this category. 49 of 120 total pages.
# Scraping departamentos alquiler, pag. 20 of 30 from this category. 50 of 120 total pages.
# Scraping departamentos alquiler, pag. 21 of 30 from this category. 51 of 120 total pages.
# Scraping departamentos alquiler, pag. 22 of 30 from this category. 52 of 120 total pages.
# Scraping departamentos alquiler, pag. 23 of 30 from this category. 53 of 120 total pages.
# Scraping departamentos alquiler, pag. 24 of 30 from this category. 54 of 120 total pages.
# Scraping departamentos alquiler, pag. 25 of 30 from this category. 55 of 120 total pages.
# Scraping departamentos alquiler, pag. 26 of 30 from this category. 56 of 120 total pages.
# Scraping departamentos alquiler, pag. 27 of 30 from this category. 57 of 120 total pages.
# Scraping departamentos alquiler, pag. 28 of 30 from this category. 58 of 120 total pages.
# Scraping departamentos alquiler, pag. 29 of 30 from this category. 59 of 120 total pages.
# Scraping departamentos alquiler, pag. 30 of 30 from this category. 60 of 120 total pages.
# Scraping casas venta, pag. 1 of 30 from this category. 61 of 120 total pages.
# Scraping casas venta, pag. 2 of 30 from this category. 62 of 120 total pages.
# Scraping casas venta, pag. 3 of 30 from this category. 63 of 120 total pages.
# Scraping casas venta, pag. 4 of 30 from this category. 64 of 120 total pages.
# Scraping casas venta, pag. 5 of 30 from this category. 65 of 120 total pages.
# Scraping casas venta, pag. 6 of 30 from this category. 66 of 120 total pages.
# Scraping casas venta, pag. 7 of 30 from this category. 67 of 120 total pages.
# Scraping casas venta, pag. 8 of 30 from this category. 68 of 120 total pages.
# Scraping casas venta, pag. 9 of 30 from this category. 69 of 120 total pages.
# Scraping casas venta, pag. 10 of 30 from this category. 70 of 120 total pages.
# Scraping casas venta, pag. 11 of 30 from this category. 71 of 120 total pages.
# Scraping casas venta, pag. 12 of 30 from this category. 72 of 120 total pages.
# Scraping casas venta, pag. 13 of 30 from this category. 73 of 120 total pages.
# Scraping casas venta, pag. 14 of 30 from this category. 74 of 120 total pages.
# Scraping casas venta, pag. 15 of 30 from this category. 75 of 120 total pages.
# Scraping casas venta, pag. 16 of 30 from this category. 76 of 120 total pages.
# Scraping casas venta, pag. 17 of 30 from this category. 77 of 120 total pages.
# Scraping casas venta, pag. 18 of 30 from this category. 78 of 120 total pages.
# Scraping casas venta, pag. 19 of 30 from this category. 79 of 120 total pages.
# Scraping casas venta, pag. 20 of 30 from this category. 80 of 120 total pages.
# Scraping casas venta, pag. 21 of 30 from this category. 81 of 120 total pages.
# Scraping casas venta, pag. 22 of 30 from this category. 82 of 120 total pages.
# Scraping casas venta, pag. 23 of 30 from this category. 83 of 120 total pages.
# Scraping casas venta, pag. 24 of 30 from this category. 84 of 120 total pages.
# Scraping casas venta, pag. 25 of 30 from this category. 85 of 120 total pages.
# Scraping casas venta, pag. 26 of 30 from this category. 86 of 120 total pages.
# Scraping casas venta, pag. 27 of 30 from this category. 87 of 120 total pages.
# Scraping casas venta, pag. 28 of 30 from this category. 88 of 120 total pages.
# Scraping casas venta, pag. 29 of 30 from this category. 89 of 120 total pages.
# Scraping casas venta, pag. 30 of 30 from this category. 90 of 120 total pages.
# Scraping casas alquiler, pag. 1 of 30 from this category. 91 of 120 total pages.
# Scraping casas alquiler, pag. 2 of 30 from this category. 92 of 120 total pages.
# Scraping casas alquiler, pag. 3 of 30 from this category. 93 of 120 total pages.
# Scraping casas alquiler, pag. 4 of 30 from this category. 94 of 120 total pages.
# Scraping casas alquiler, pag. 5 of 30 from this category. 95 of 120 total pages.
# Scraping casas alquiler, pag. 6 of 30 from this category. 96 of 120 total pages.
# Scraping casas alquiler, pag. 7 of 30 from this category. 97 of 120 total pages.
# Scraping casas alquiler, pag. 8 of 30 from this category. 98 of 120 total pages.
# Scraping casas alquiler, pag. 9 of 30 from this category. 99 of 120 total pages.
# Scraping casas alquiler, pag. 10 of 30 from this category. 100 of 120 total pages.
# Scraping casas alquiler, pag. 11 of 30 from this category. 101 of 120 total pages.
# Scraping casas alquiler, pag. 12 of 30 from this category. 102 of 120 total pages.
# Scraping casas alquiler, pag. 13 of 30 from this category. 103 of 120 total pages.
# Scraping casas alquiler, pag. 14 of 30 from this category. 104 of 120 total pages.
# Scraping casas alquiler, pag. 15 of 30 from this category. 105 of 120 total pages.
# Scraping casas alquiler, pag. 16 of 30 from this category. 106 of 120 total pages.
# Scraping casas alquiler, pag. 17 of 30 from this category. 107 of 120 total pages.
# Scraping casas alquiler, pag. 18 of 30 from this category. 108 of 120 total pages.
# Scraping casas alquiler, pag. 19 of 30 from this category. 109 of 120 total pages.
# Scraping casas alquiler, pag. 20 of 30 from this category. 110 of 120 total pages.
# Scraping casas alquiler, pag. 21 of 30 from this category. 111 of 120 total pages.
# Scraping casas alquiler, pag. 22 of 30 from this category. 112 of 120 total pages.
# Scraping casas alquiler, pag. 23 of 30 from this category. 113 of 120 total pages.
# Scraping casas alquiler, pag. 24 of 30 from this category. 114 of 120 total pages.
# Scraping casas alquiler, pag. 25 of 30 from this category. 115 of 120 total pages.
# Scraping casas alquiler, pag. 26 of 30 from this category. 116 of 120 total pages.
# Scraping casas alquiler, pag. 27 of 30 from this category. 117 of 120 total pages.
# Scraping casas alquiler, pag. 28 of 30 from this category. 118 of 120 total pages.
# Scraping casas alquiler, pag. 29 of 30 from this category. 119 of 120 total pages.
# Scraping casas alquiler, pag. 30 of 30 from this category. 120 of 120 total pages.
# This took 115.124975391229 minutes, or 57.5624876956145 seconds per page.

# %% [markdown]
# # Zonaprop

# %%
def scrape_zonaprop(url_zp):

    driver = webdriver.Chrome(ChromeDriverManager().install())

    driver.get(url_zp)
    sleep(5)
    driver.get(url_zp)
    
    sleep(60)

    all_data_zp = []

    # Links
    start_link_zp = 'https://www.zonaprop.com.ar'
    links_zp = driver.find_elements(By.XPATH, '//*/div[@data-to-posting]')
    links_zp = [start_link_zp+l.get_attribute('data-to-posting') for l in links_zp]
    all_data_zp.append(links_zp)

    # Service
    all_data_zp.append(['zona_prop']*len(links_zp))

    # City
    city_zp = driver.find_elements(By.XPATH, '//*/div[@data-qa="POSTING_CARD_LOCATION"]')
    city_zp = [c.text for c in city_zp]
    all_data_zp.append(city_zp)

    # Adress
    adress_zp = driver.find_elements(By.XPATH, '//*/div[@class="sc-ge2uzh-0 bzGYzE"]')
    adress_zp = [c.text for c in adress_zp]
    all_data_zp.append(adress_zp)

    # Property type
    if 'casa' in url_zp:
        property_type_zp = ['casa']*len(links_zp)
    else:
        property_type_zp = ['departamento']*len(links_zp)
    all_data_zp.append(property_type_zp)

    # Contract Type
    if 'alquiler' in url_zp:
        contract_type_zp = ['alquiler']*len(links_zp)
    else:
        contract_type_zp = ['venta']*len(links_zp)
    all_data_zp.append(contract_type_zp)

    # Rooms and Squared Meters
    squared_meters_and_rooms_zp = driver.find_elements(By.XPATH, '//*/div[@data-qa="POSTING_CARD_FEATURES"]')
    squared_meters_and_rooms_zp = [sm.text for sm in squared_meters_and_rooms_zp]
    rooms_zp = []
    squared_meters_zp = []
    for smr in squared_meters_and_rooms_zp:
        amb = re.findall('(\d+)\s(?:ambiente|dorm\.)', smr)
        if len(amb)>0:
            rooms_zp.append(int(amb[0]))
        else:
            rooms_zp.append(1)
        
        m2 = re.findall('(\d+)\s*m²', smr)
        if len(m2)>0:
            squared_meters_zp.append(int(m2[0]))
        else:
            squared_meters_zp.append(0)
    all_data_zp.append(rooms_zp)
    all_data_zp.append(squared_meters_zp)


    # All price and currency
    all_price_and_currency_zp = driver.find_elements(By.XPATH, '//*/div[@class="sc-12dh9kl-0 cysiyu"]')
    all_price_and_currency_zp = [l.text.lower().strip() for l in all_price_and_currency_zp]

    expensas_currency = []
    expensas_price = []
    buy_rent_currency = []
    buy_rent_price = []

    for pc in all_price_and_currency_zp:
        all_matches = re.findall('(?:usd|\$)\s*\d*(?:[,.]\d*)*(?:\s*expensas)*', pc)
        found_expensas = False
        if len(all_matches)>0:
            for am in all_matches:
                if 'expensas' in am:
                    expensas_currency.append(['$' if '$' in am else 'USD'][0])
                    expensas_price.append(price_multiple_replace(re.findall('\d+(?:[,.]\d*)*', am)[0]))
                    found_expensas = True
                else:
                    buy_rent_currency.append(['$' if '$' in am else 'USD'][0])
                    buy_rent_price.append(price_multiple_replace(re.findall('\d+(?:[,.]\d*)*', am)[0]))
                
            if not found_expensas:
                expensas_currency.append('consult_currency')
                expensas_price.append('consult_price')
                    
        else:
            expensas_currency.append('consult_currency')
            expensas_price.append('consult_price')
            buy_rent_currency.append('consult_currency')
            buy_rent_price.append('consult_price')
    
    all_data_zp.append(buy_rent_currency)
    all_data_zp.append(expensas_currency)
    all_data_zp.append(buy_rent_price)
    all_data_zp.append(buy_rent_price)
                    
    driver.close()
    return all_data_zp

# %%
all_url_zp = [
              'https://www.zonaprop.com.ar/departamentos-venta-pagina-NRO_PAGINA.html',
              'https://www.zonaprop.com.ar/departamentos-alquiler-pagina-NRO_PAGINA.html',
              'https://www.zonaprop.com.ar/casas-alquiler-pagina-NRO_PAGINA.html',
              'https://www.zonaprop.com.ar/casas-venta-pagina-NRO_PAGINA.html']

cantidad_paginas_a_scrapear = {
                                'departamentos venta':5,
                                'departamentos alquiler':5,
                                'casas venta':5,
                                'casas alquiler':5,
                                }

total_pages = sum(cantidad_paginas_a_scrapear.values())
page_counter = 0

t1 = time.time()

all_columns_zp = []
for i_url, url_zp in enumerate(all_url_zp): # iterate general URLs
    cant_pag = list(cantidad_paginas_a_scrapear.values())[i_url]
    categorie = list(cantidad_paginas_a_scrapear.keys())[i_url]
    for pag in range(cant_pag): # iterate paginas
        
        page_counter += 1
        print(f'Scraping {categorie}, pag. {pag+1} of {cant_pag} from this category. {page_counter} of {total_pages} total pages.')
        
        this_url = url_zp.replace('NRO_PAGINA',str(pag+1)) #define page number
        
        all_columns_zp.append(scrape_zonaprop(this_url))

t2 = time.time()

print(f'This took {(t2-t1)/60} minutes, or {round((t2-t1)/200)} seconds per page.')
# Out:
# Scraping departamentos venta, pag. 1 of 5 from this category. 1 of 20 total pages.
# C:\Users\Felipe\AppData\Local\Temp\ipykernel_16856\2168744578.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# Scraping departamentos venta, pag. 2 of 5 from this category. 2 of 20 total pages.
# Scraping departamentos venta, pag. 3 of 5 from this category. 3 of 20 total pages.
# Scraping departamentos venta, pag. 4 of 5 from this category. 4 of 20 total pages.
# Scraping departamentos venta, pag. 5 of 5 from this category. 5 of 20 total pages.
# Scraping departamentos alquiler, pag. 1 of 5 from this category. 6 of 20 total pages.
# Scraping departamentos alquiler, pag. 2 of 5 from this category. 7 of 20 total pages.
# Scraping departamentos alquiler, pag. 3 of 5 from this category. 8 of 20 total pages.
# Scraping departamentos alquiler, pag. 4 of 5 from this category. 9 of 20 total pages.
# Scraping departamentos alquiler, pag. 5 of 5 from this category. 10 of 20 total pages.
# Scraping casas venta, pag. 1 of 5 from this category. 11 of 20 total pages.
# Scraping casas venta, pag. 2 of 5 from this category. 12 of 20 total pages.
# Scraping casas venta, pag. 3 of 5 from this category. 13 of 20 total pages.
# Scraping casas venta, pag. 4 of 5 from this category. 14 of 20 total pages.
# Scraping casas venta, pag. 5 of 5 from this category. 15 of 20 total pages.
# Scraping casas alquiler, pag. 1 of 5 from this category. 16 of 20 total pages.
# Scraping casas alquiler, pag. 2 of 5 from this category. 17 of 20 total pages.
# Scraping casas alquiler, pag. 3 of 5 from this category. 18 of 20 total pages.
# Scraping casas alquiler, pag. 4 of 5 from this category. 19 of 20 total pages.
# Scraping casas alquiler, pag. 5 of 5 from this category. 20 of 20 total pages.
# This took 24.80328387816747 minutes, or 7 seconds per page.

# %% [markdown]
# # Dataframe

# %%
# Combine each of the 12 (city, price, etc) columns found in each of the N pages scraped
amount_columns = 12

ml_combined = [ [item for sublist in all_columns_ml for item in sublist[i]] for i in range(amount_columns)]
ap_combined = [ [item for sublist in all_columns_ap for item in sublist[i]] for i in range(amount_columns)]
zp_combined = [ [item for sublist in all_columns_zp for item in sublist[i]] for i in range(amount_columns)]

# Combine every scrapped web
all_columns = []
for i in range(amount_columns):
    all_columns.append(ml_combined[i]+ap_combined[i]+zp_combined[i])
    
# Construct df
col_names = ['link','service','city','adress','property_type','contract_type',
             'rooms','squared_meters','buy_rent_currency','expensas_currency','buy_rent_price','expensas_price']
df = pd.DataFrame(all_columns).T
df.columns = col_names

# Create total price per month
df['total_price'] = df['buy_rent_price'] + df['expensas_price']

# fill nans (not int, since it would alter central tendency measures)
df['link'].fillna('no_info', inplace=True)
df['adress'].fillna('no_info', inplace=True)
df['city'].fillna('no_info', inplace=True)
df['expensas_currency'].fillna('consult_currency', inplace=True)
df['buy_rent_currency'].fillna('consult_currency', inplace=True)
df['expensas_currency'].fillna('consult_currency', inplace=True)

# %% [markdown]
# ## Save

# %%
# Checkpoint
# df.to_csv('scraped_df.csv', index=False)

# %% [markdown]
# ## Load

# %%
# Checkpoint
df = pd.read_csv('scraped_df.csv')
